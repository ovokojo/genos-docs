# %% [markdown]
# # Langchain RAG Tutorial
# ---
# <br>
#
# ## Install dependencies
#
# 1. Do the following before installing the dependencies found in `requirements.txt` file because of current challenges installing `onnxruntime` through `pip install onnxruntime`.
#
#     - For MacOS users, a workaround is to first install `onnxruntime` dependency for `chromadb` using:
#
#     ```python
#      conda install onnxruntime -c conda-forge
#     ```
#     See this [thread](https://github.com/microsoft/onnxruntime/issues/11037) for additonal help if needed.
#
#      - For Windows users, follow the guide [here](https://github.com/bycloudai/InstallVSBuildToolsWindows?tab=readme-ov-file) to install the Microsoft C++ Build Tools. Be sure to follow through to the last step to set the enviroment variable path.
#
#
# 2. Now run this command to install dependenies in the `requirements.txt` file.
#
# ```python
# pip install -r requirements.txt
# ```
#
# 3. Install markdown depenendies with:
#
# ```python
# pip install "unstructured[md]"
# ```
#
# You'll also need to set up an OpenAI account (and set the OpenAI key in your environment variable) for this to work.
# <br>
#
# ### References
#
# Instructions and code snippets from [Langchain RAG Tutorial](https://github.com/pixegami/langchain-rag-tutorial)

# %%
pip install -r requirements.txt
# Out:
# Collecting python-dotenv==1.0.1 (from -r requirements.txt (line 1))
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Collecting langchain==0.2.2 (from -r requirements.txt (line 2))
#   Downloading langchain-0.2.2-py3-none-any.whl.metadata (13 kB)
# Collecting langchain-community==0.2.3 (from -r requirements.txt (line 3))
#   Downloading langchain_community-0.2.3-py3-none-any.whl.metadata (9.0 kB)
# Collecting langchain-openai==0.1.8 (from -r requirements.txt (line 4))
#   Downloading langchain_openai-0.1.8-py3-none-any.whl.metadata (2.5 kB)
# Collecting unstructured==0.14.4 (from -r requirements.txt (line 5))
#   Downloading unstructured-0.14.4-py3-none-any.whl.metadata (28 kB)
# Collecting chromadb==0.5.0 (from -r requirements.txt (line 9))
#   Downloading chromadb-0.5.0-py3-none-any.whl.metadata (7.3 kB)
# Collecting openai==1.31.1 (from -r requirements.txt (line 10))
#   Downloading openai-1.31.1-py3-none-any.whl.metadata (21 kB)
# Collecting tiktoken==0.7.0 (from -r requirements.txt (line 11))
#   Downloading tiktoken-0.7.0-cp310-cp310-macosx_10_9_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: PyYAML>=5.3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from langchain==0.2.2->-r requirements.txt (line 2)) (6.0.1)
# Collecting SQLAlchemy<3,>=1.4 (from langchain==0.2.2->-r requirements.txt (line 2))
#   Downloading SQLAlchemy-2.0.31-cp310-cp310-macosx_10_9_x86_64.whl.metadata (9.6 kB)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain==0.2.2->-r requirements.txt (line 2))
#   Downloading aiohttp-3.9.5-cp310-cp310-macosx_10_9_x86_64.whl.metadata (7.5 kB)
# Collecting async-timeout<5.0.0,>=4.0.0 (from langchain==0.2.2->-r requirements.txt (line 2))
#   Downloading async_timeout-4.0.3-py3-none-any.whl.metadata (4.2 kB)
# Collecting langchain-core<0.3.0,>=0.2.0 (from langchain==0.2.2->-r requirements.txt (line 2))
#   Downloading langchain_core-0.2.10-py3-none-any.whl.metadata (6.0 kB)
# Collecting langchain-text-splitters<0.3.0,>=0.2.0 (from langchain==0.2.2->-r requirements.txt (line 2))
#   Downloading langchain_text_splitters-0.2.2-py3-none-any.whl.metadata (2.1 kB)
# Collecting langsmith<0.2.0,>=0.1.17 (from langchain==0.2.2->-r requirements.txt (line 2))
#   Downloading langsmith-0.1.82-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy<2,>=1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from langchain==0.2.2->-r requirements.txt (line 2)) (1.26.4)
# Requirement already satisfied: pydantic<3,>=1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from langchain==0.2.2->-r requirements.txt (line 2)) (2.7.4)
# Requirement already satisfied: requests<3,>=2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from langchain==0.2.2->-r requirements.txt (line 2)) (2.32.3)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from langchain==0.2.2->-r requirements.txt (line 2)) (8.4.2)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain-community==0.2.3->-r requirements.txt (line 3))
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: chardet in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from unstructured==0.14.4->-r requirements.txt (line 5)) (4.0.0)
# Collecting filetype (from unstructured==0.14.4->-r requirements.txt (line 5))
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting python-magic (from unstructured==0.14.4->-r requirements.txt (line 5))
#   Downloading python_magic-0.4.27-py2.py3-none-any.whl.metadata (5.8 kB)
# Collecting lxml (from unstructured==0.14.4->-r requirements.txt (line 5))
#   Downloading lxml-5.2.2-cp310-cp310-macosx_10_9_x86_64.whl.metadata (3.4 kB)
# Requirement already satisfied: nltk in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from unstructured==0.14.4->-r requirements.txt (line 5)) (3.6.5)
# Collecting tabulate (from unstructured==0.14.4->-r requirements.txt (line 5))
#   Downloading tabulate-0.9.0-py3-none-any.whl.metadata (34 kB)
# Collecting beautifulsoup4 (from unstructured==0.14.4->-r requirements.txt (line 5))
#   Downloading beautifulsoup4-4.12.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting emoji (from unstructured==0.14.4->-r requirements.txt (line 5))
#   Downloading emoji-2.12.1-py3-none-any.whl.metadata (5.4 kB)
# Collecting python-iso639 (from unstructured==0.14.4->-r requirements.txt (line 5))
#   Downloading python_iso639-2024.4.27-py3-none-any.whl.metadata (13 kB)
# Collecting langdetect (from unstructured==0.14.4->-r requirements.txt (line 5))
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 14.5 MB/s eta 0:00:00a 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting rapidfuzz (from unstructured==0.14.4->-r requirements.txt (line 5))
#   Downloading rapidfuzz-3.9.3-cp310-cp310-macosx_10_9_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: backoff in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from unstructured==0.14.4->-r requirements.txt (line 5)) (2.2.1)
# Requirement already satisfied: typing-extensions in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from unstructured==0.14.4->-r requirements.txt (line 5)) (4.12.2)
# Collecting unstructured-client (from unstructured==0.14.4->-r requirements.txt (line 5))
#   Downloading unstructured_client-0.23.8-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: wrapt in /Users/thomaskojoaddaquay/Library/Python/3.10/lib/python/site-packages (from unstructured==0.14.4->-r requirements.txt (line 5)) (1.12.1)
# Requirement already satisfied: build>=1.0.3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from chromadb==0.5.0->-r requirements.txt (line 9)) (1.2.1)
# Requirement already satisfied: chroma-hnswlib==0.7.3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from chromadb==0.5.0->-r requirements.txt (line 9)) (0.7.3)
# Requirement already satisfied: fastapi>=0.95.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from chromadb==0.5.0->-r requirements.txt (line 9)) (0.111.0)
# Requirement already satisfied: uvicorn>=0.18.3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb==0.5.0->-r requirements.txt (line 9)) (0.30.1)
# Requirement already satisfied: posthog>=2.4.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from chromadb==0.5.0->-r requirements.txt (line 9)) (3.5.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from chromadb==0.5.0->-r requirements.txt (line 9)) (1.18.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from chromadb==0.5.0->-r requirements.txt (line 9)) (1.25.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from chromadb==0.5.0->-r requirements.txt (line 9)) (1.25.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from chromadb==0.5.0->-r requirements.txt (line 9)) (0.46b0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from chromadb==0.5.0->-r requirements.txt (line 9)) (1.25.0)
# Requirement already satisfied: tokenizers>=0.13.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from chromadb==0.5.0->-r requirements.txt (line 9)) (0.19.1)
# Requirement already satisfied: pypika>=0.48.9 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from chromadb==0.5.0->-r requirements.txt (line 9)) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from chromadb==0.5.0->-r requirements.txt (line 9)) (4.66.4)
# Requirement already satisfied: overrides>=7.3.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from chromadb==0.5.0->-r requirements.txt (line 9)) (7.7.0)
# Requirement already satisfied: importlib-resources in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from chromadb==0.5.0->-r requirements.txt (line 9)) (6.4.0)
# Requirement already satisfied: grpcio>=1.58.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from chromadb==0.5.0->-r requirements.txt (line 9)) (1.64.1)
# Requirement already satisfied: bcrypt>=4.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from chromadb==0.5.0->-r requirements.txt (line 9)) (4.1.3)
# Requirement already satisfied: typer>=0.9.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from chromadb==0.5.0->-r requirements.txt (line 9)) (0.12.3)
# Requirement already satisfied: kubernetes>=28.1.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from chromadb==0.5.0->-r requirements.txt (line 9)) (30.1.0)
# Requirement already satisfied: mmh3>=4.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from chromadb==0.5.0->-r requirements.txt (line 9)) (4.1.0)
# Requirement already satisfied: orjson>=3.9.12 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from chromadb==0.5.0->-r requirements.txt (line 9)) (3.10.5)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from openai==1.31.1->-r requirements.txt (line 10)) (4.4.0)
# Collecting distro<2,>=1.7.0 (from openai==1.31.1->-r requirements.txt (line 10))
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from openai==1.31.1->-r requirements.txt (line 10)) (0.27.0)
# Requirement already satisfied: sniffio in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from openai==1.31.1->-r requirements.txt (line 10)) (1.3.1)
# Collecting regex>=2022.1.18 (from tiktoken==0.7.0->-r requirements.txt (line 11))
#   Downloading regex-2024.5.15-cp310-cp310-macosx_10_9_x86_64.whl.metadata (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 kB 2.0 MB/s eta 0:00:00
# Collecting aiosignal>=1.1.2 (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.2->-r requirements.txt (line 2))
#   Downloading aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: attrs>=17.3.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.2->-r requirements.txt (line 2)) (21.2.0)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.2->-r requirements.txt (line 2))
#   Downloading frozenlist-1.4.1-cp310-cp310-macosx_10_9_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/thomaskojoaddaquay/Library/Python/3.10/lib/python/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.2->-r requirements.txt (line 2)) (5.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/thomaskojoaddaquay/Library/Python/3.10/lib/python/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.2->-r requirements.txt (line 2)) (1.6.3)
# Requirement already satisfied: idna>=2.8 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai==1.31.1->-r requirements.txt (line 10)) (3.2)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai==1.31.1->-r requirements.txt (line 10)) (1.2.1)
# Requirement already satisfied: packaging>=19.1 in /Users/thomaskojoaddaquay/Library/Python/3.10/lib/python/site-packages (from build>=1.0.3->chromadb==0.5.0->-r requirements.txt (line 9)) (21.0)
# Requirement already satisfied: pyproject_hooks in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from build>=1.0.3->chromadb==0.5.0->-r requirements.txt (line 9)) (1.1.0)
# Requirement already satisfied: importlib-metadata>=4.6 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from build>=1.0.3->chromadb==0.5.0->-r requirements.txt (line 9)) (7.1.0)
# Requirement already satisfied: tomli>=1.1.0 in /Users/thomaskojoaddaquay/Library/Python/3.10/lib/python/site-packages (from build>=1.0.3->chromadb==0.5.0->-r requirements.txt (line 9)) (1.2.1)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community==0.2.3->-r requirements.txt (line 3))
#   Downloading marshmallow-3.21.3-py3-none-any.whl.metadata (7.1 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community==0.2.3->-r requirements.txt (line 3))
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: starlette<0.38.0,>=0.37.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from fastapi>=0.95.2->chromadb==0.5.0->-r requirements.txt (line 9)) (0.37.2)
# Requirement already satisfied: fastapi-cli>=0.0.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from fastapi>=0.95.2->chromadb==0.5.0->-r requirements.txt (line 9)) (0.0.4)
# Requirement already satisfied: jinja2>=2.11.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from fastapi>=0.95.2->chromadb==0.5.0->-r requirements.txt (line 9)) (3.0.3)
# Requirement already satisfied: python-multipart>=0.0.7 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from fastapi>=0.95.2->chromadb==0.5.0->-r requirements.txt (line 9)) (0.0.9)
# Requirement already satisfied: ujson!=4.0.2,!=4.1.0,!=4.2.0,!=4.3.0,!=5.0.0,!=5.1.0,>=4.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from fastapi>=0.95.2->chromadb==0.5.0->-r requirements.txt (line 9)) (5.10.0)
# Requirement already satisfied: email_validator>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from fastapi>=0.95.2->chromadb==0.5.0->-r requirements.txt (line 9)) (2.2.0)
# Requirement already satisfied: certifi in /Users/thomaskojoaddaquay/Library/Python/3.10/lib/python/site-packages (from httpx<1,>=0.23.0->openai==1.31.1->-r requirements.txt (line 10)) (2021.5.30)
# Requirement already satisfied: httpcore==1.* in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai==1.31.1->-r requirements.txt (line 10)) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai==1.31.1->-r requirements.txt (line 10)) (0.14.0)
# Requirement already satisfied: six>=1.9.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb==0.5.0->-r requirements.txt (line 9)) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /Users/thomaskojoaddaquay/Library/Python/3.10/lib/python/site-packages (from kubernetes>=28.1.0->chromadb==0.5.0->-r requirements.txt (line 9)) (2.8.1)
# Requirement already satisfied: google-auth>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb==0.5.0->-r requirements.txt (line 9)) (2.30.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb==0.5.0->-r requirements.txt (line 9)) (1.8.0)
# Requirement already satisfied: requests-oauthlib in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb==0.5.0->-r requirements.txt (line 9)) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb==0.5.0->-r requirements.txt (line 9)) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in /Users/thomaskojoaddaquay/Library/Python/3.10/lib/python/site-packages (from kubernetes>=28.1.0->chromadb==0.5.0->-r requirements.txt (line 9)) (1.26.6)
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core<0.3.0,>=0.2.0->langchain==0.2.2->-r requirements.txt (line 2))
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting packaging>=19.1 (from build>=1.0.3->chromadb==0.5.0->-r requirements.txt (line 9))
#   Downloading packaging-24.1-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: coloredlogs in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb==0.5.0->-r requirements.txt (line 9)) (15.0.1)
# Requirement already satisfied: flatbuffers in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb==0.5.0->-r requirements.txt (line 9)) (24.3.25)
# Requirement already satisfied: protobuf in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb==0.5.0->-r requirements.txt (line 9)) (3.18.1)
# Requirement already satisfied: sympy in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb==0.5.0->-r requirements.txt (line 9)) (1.12.1)
# Requirement already satisfied: deprecated>=1.2.6 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from opentelemetry-api>=1.2.0->chromadb==0.5.0->-r requirements.txt (line 9)) (1.2.14)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb==0.5.0->-r requirements.txt (line 9)) (1.63.2)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.25.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb==0.5.0->-r requirements.txt (line 9)) (1.25.0)
# Requirement already satisfied: opentelemetry-proto==1.25.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb==0.5.0->-r requirements.txt (line 9)) (1.25.0)
# Collecting protobuf (from onnxruntime>=1.14.1->chromadb==0.5.0->-r requirements.txt (line 9))
#   Downloading protobuf-4.25.3-cp37-abi3-macosx_10_9_universal2.whl.metadata (541 bytes)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.46b0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.5.0->-r requirements.txt (line 9)) (0.46b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.46b0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.5.0->-r requirements.txt (line 9)) (0.46b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.46b0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.5.0->-r requirements.txt (line 9)) (0.46b0)
# Requirement already satisfied: opentelemetry-util-http==0.46b0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.5.0->-r requirements.txt (line 9)) (0.46b0)
# Requirement already satisfied: setuptools>=16.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from opentelemetry-instrumentation==0.46b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.5.0->-r requirements.txt (line 9)) (57.4.0)
# Requirement already satisfied: asgiref~=3.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from opentelemetry-instrumentation-asgi==0.46b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.5.0->-r requirements.txt (line 9)) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from posthog>=2.4.0->chromadb==0.5.0->-r requirements.txt (line 9)) (1.6)
# Requirement already satisfied: annotated-types>=0.4.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pydantic<3,>=1->langchain==0.2.2->-r requirements.txt (line 2)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pydantic<3,>=1->langchain==0.2.2->-r requirements.txt (line 2)) (2.18.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests<3,>=2->langchain==0.2.2->-r requirements.txt (line 2)) (2.0.6)
# Collecting greenlet!=0.4.17 (from SQLAlchemy<3,>=1.4->langchain==0.2.2->-r requirements.txt (line 2))
#   Downloading greenlet-3.0.3-cp310-cp310-macosx_11_0_universal2.whl.metadata (3.8 kB)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tokenizers>=0.13.2->chromadb==0.5.0->-r requirements.txt (line 9)) (0.23.4)
# Requirement already satisfied: click>=8.0.0 in /Users/thomaskojoaddaquay/Library/Python/3.10/lib/python/site-packages (from typer>=0.9.0->chromadb==0.5.0->-r requirements.txt (line 9)) (8.0.1)
# Requirement already satisfied: shellingham>=1.3.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from typer>=0.9.0->chromadb==0.5.0->-r requirements.txt (line 9)) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from typer>=0.9.0->chromadb==0.5.0->-r requirements.txt (line 9)) (13.7.1)
# Requirement already satisfied: httptools>=0.5.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb==0.5.0->-r requirements.txt (line 9)) (0.6.1)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb==0.5.0->-r requirements.txt (line 9)) (0.19.0)
# Requirement already satisfied: watchfiles>=0.13 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb==0.5.0->-r requirements.txt (line 9)) (0.22.0)
# Requirement already satisfied: websockets>=10.4 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb==0.5.0->-r requirements.txt (line 9)) (12.0)
# Collecting soupsieve>1.2 (from beautifulsoup4->unstructured==0.14.4->-r requirements.txt (line 5))
#   Downloading soupsieve-2.5-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: joblib in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from nltk->unstructured==0.14.4->-r requirements.txt (line 5)) (1.1.0)
# Collecting certifi (from httpx<1,>=0.23.0->openai==1.31.1->-r requirements.txt (line 10))
#   Downloading certifi-2024.6.2-py3-none-any.whl.metadata (2.2 kB)
# Collecting charset-normalizer<4,>=2 (from requests<3,>=2->langchain==0.2.2->-r requirements.txt (line 2))
#   Downloading charset_normalizer-3.3.2-cp310-cp310-macosx_10_9_x86_64.whl.metadata (33 kB)
# Collecting deepdiff>=6.0 (from unstructured-client->unstructured==0.14.4->-r requirements.txt (line 5))
#   Downloading deepdiff-7.0.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting idna>=2.8 (from anyio<5,>=3.5.0->openai==1.31.1->-r requirements.txt (line 10))
#   Downloading idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Collecting jsonpath-python>=1.0.6 (from unstructured-client->unstructured==0.14.4->-r requirements.txt (line 5))
#   Downloading jsonpath_python-1.0.6-py3-none-any.whl.metadata (12 kB)
# Collecting mypy-extensions>=1.0.0 (from unstructured-client->unstructured==0.14.4->-r requirements.txt (line 5))
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting nest-asyncio>=1.6.0 (from unstructured-client->unstructured==0.14.4->-r requirements.txt (line 5))
#   Downloading nest_asyncio-1.6.0-py3-none-any.whl.metadata (2.8 kB)
# Collecting pypdf>=4.0 (from unstructured-client->unstructured==0.14.4->-r requirements.txt (line 5))
#   Downloading pypdf-4.2.0-py3-none-any.whl.metadata (7.4 kB)
# Collecting python-dateutil>=2.5.3 (from kubernetes>=28.1.0->chromadb==0.5.0->-r requirements.txt (line 9))
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting requests-toolbelt>=1.0.0 (from unstructured-client->unstructured==0.14.4->-r requirements.txt (line 5))
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting urllib3>=1.24.2 (from kubernetes>=28.1.0->chromadb==0.5.0->-r requirements.txt (line 9))
#   Downloading urllib3-2.2.2-py3-none-any.whl.metadata (6.4 kB)
# Collecting ordered-set<4.2.0,>=4.1.0 (from deepdiff>=6.0->unstructured-client->unstructured==0.14.4->-r requirements.txt (line 5))
#   Downloading ordered_set-4.1.0-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: dnspython>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from email_validator>=2.0.0->fastapi>=0.95.2->chromadb==0.5.0->-r requirements.txt (line 9)) (2.6.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb==0.5.0->-r requirements.txt (line 9)) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb==0.5.0->-r requirements.txt (line 9)) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb==0.5.0->-r requirements.txt (line 9)) (4.9)
# Requirement already satisfied: filelock in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb==0.5.0->-r requirements.txt (line 9)) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb==0.5.0->-r requirements.txt (line 9)) (2024.6.0)
# Requirement already satisfied: zipp>=0.5 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from importlib-metadata>=4.6->build>=1.0.3->chromadb==0.5.0->-r requirements.txt (line 9)) (3.19.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from jinja2>=2.11.2->fastapi>=0.95.2->chromadb==0.5.0->-r requirements.txt (line 9)) (2.0.1)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.0->langchain==0.2.2->-r requirements.txt (line 2))
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from rich>=10.11.0->typer>=0.9.0->chromadb==0.5.0->-r requirements.txt (line 9)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from rich>=10.11.0->typer>=0.9.0->chromadb==0.5.0->-r requirements.txt (line 9)) (2.18.0)
# Requirement already satisfied: humanfriendly>=9.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb==0.5.0->-r requirements.txt (line 9)) (10.0)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from sympy->onnxruntime>=1.14.1->chromadb==0.5.0->-r requirements.txt (line 9)) (1.3.0)
# Requirement already satisfied: mdurl~=0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.9.0->chromadb==0.5.0->-r requirements.txt (line 9)) (0.1.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb==0.5.0->-r requirements.txt (line 9)) (0.6.0)
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading langchain-0.2.2-py3-none-any.whl (973 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 973.6/973.6 kB 12.1 MB/s eta 0:00:0000:0100:01
# Downloading langchain_community-0.2.3-py3-none-any.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 6.6 MB/s eta 0:00:0000:0100:010m
# Downloading langchain_openai-0.1.8-py3-none-any.whl (38 kB)
# Downloading unstructured-0.14.4-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 21.4 MB/s eta 0:00:0000:0100:01
# Downloading chromadb-0.5.0-py3-none-any.whl (526 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 526.8/526.8 kB 13.0 MB/s eta 0:00:0000:01
# Downloading openai-1.31.1-py3-none-any.whl (324 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 324.1/324.1 kB 15.3 MB/s eta 0:00:00
# Downloading tiktoken-0.7.0-cp310-cp310-macosx_10_9_x86_64.whl (961 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 961.5/961.5 kB 22.2 MB/s eta 0:00:0000:01
# Downloading aiohttp-3.9.5-cp310-cp310-macosx_10_9_x86_64.whl (400 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.7/400.7 kB 19.7 MB/s eta 0:00:00
# Downloading async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading langchain_core-0.2.10-py3-none-any.whl (332 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 332.8/332.8 kB 25.1 MB/s eta 0:00:00
# Downloading langchain_text_splitters-0.2.2-py3-none-any.whl (25 kB)
# Downloading langsmith-0.1.82-py3-none-any.whl (127 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.4/127.4 kB 11.6 MB/s eta 0:00:00
# Downloading regex-2024.5.15-cp310-cp310-macosx_10_9_x86_64.whl (281 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 281.7/281.7 kB 25.1 MB/s eta 0:00:00
# Downloading SQLAlchemy-2.0.31-cp310-cp310-macosx_10_9_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 45.2 MB/s eta 0:00:0000:01
# Downloading beautifulsoup4-4.12.3-py3-none-any.whl (147 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.9/147.9 kB 9.8 MB/s eta 0:00:00
# Downloading emoji-2.12.1-py3-none-any.whl (431 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 431.4/431.4 kB 23.5 MB/s eta 0:00:00
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading lxml-5.2.2-cp310-cp310-macosx_10_9_x86_64.whl (4.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 22.0 MB/s eta 0:00:0000:0100:01
# Downloading python_iso639-2024.4.27-py3-none-any.whl (274 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 274.7/274.7 kB 9.0 MB/s eta 0:00:00
# Downloading python_magic-0.4.27-py2.py3-none-any.whl (13 kB)
# Downloading rapidfuzz-3.9.3-cp310-cp310-macosx_10_9_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 29.7 MB/s eta 0:00:0000:01
# Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Downloading unstructured_client-0.23.8-py3-none-any.whl (40 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.0/41.0 kB 532.8 kB/s eta 0:00:00a 0:00:01
# Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Downloading certifi-2024.6.2-py3-none-any.whl (164 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.4/164.4 kB 10.4 MB/s eta 0:00:00
# Downloading charset_normalizer-3.3.2-cp310-cp310-macosx_10_9_x86_64.whl (122 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.5/122.5 kB 10.3 MB/s eta 0:00:00
# Downloading deepdiff-7.0.1-py3-none-any.whl (80 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.8/80.8 kB 4.4 MB/s eta 0:00:00
# Downloading frozenlist-1.4.1-cp310-cp310-macosx_10_9_x86_64.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.8/53.8 kB 3.8 MB/s eta 0:00:00
# Downloading greenlet-3.0.3-cp310-cp310-macosx_11_0_universal2.whl (270 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 270.1/270.1 kB 16.4 MB/s eta 0:00:00
# Downloading idna-3.7-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 5.0 MB/s eta 0:00:00
# Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading jsonpath_python-1.0.6-py3-none-any.whl (7.6 kB)
# Downloading marshmallow-3.21.3-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.2/49.2 kB 2.8 MB/s eta 0:00:00
# Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Downloading nest_asyncio-1.6.0-py3-none-any.whl (5.2 kB)
# Downloading packaging-24.1-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.0/54.0 kB 5.4 MB/s eta 0:00:00
# Downloading protobuf-4.25.3-cp37-abi3-macosx_10_9_universal2.whl (394 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 394.2/394.2 kB 26.3 MB/s eta 0:00:00
# Downloading pypdf-4.2.0-py3-none-any.whl (290 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.4/290.4 kB 17.9 MB/s eta 0:00:00
# Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.9/229.9 kB 19.0 MB/s eta 0:00:00
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 4.2 MB/s eta 0:00:00
# Downloading soupsieve-2.5-py3-none-any.whl (36 kB)
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading urllib3-2.2.2-py3-none-any.whl (121 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.4/121.4 kB 12.5 MB/s eta 0:00:00
# Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Downloading ordered_set-4.1.0-py3-none-any.whl (7.6 kB)
# Building wheels for collected packages: langdetect
#   Building wheel for langdetect (pyproject.toml) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993221 sha256=2ef9161a8b31bb1fab7fa86e400e4fc8ab31eac5fb3a9cf1747569c365e4ea96
#   Stored in directory: /Users/thomaskojoaddaquay/Library/Caches/pip/wheels/95/03/7d/59ea870c70ce4e5a370638b5462a7711ab78fba2f655d05106
# Successfully built langdetect
# Installing collected packages: filetype, urllib3, tabulate, soupsieve, regex, rapidfuzz, python-magic, python-iso639, python-dotenv, python-dateutil, pypdf, protobuf, packaging, ordered-set, nest-asyncio, mypy-extensions, lxml, langdetect, jsonpointer, jsonpath-python, idna, greenlet, frozenlist, emoji, distro, charset-normalizer, certifi, async-timeout, typing-inspect, SQLAlchemy, marshmallow, jsonpatch, deepdiff, beautifulsoup4, aiosignal, tiktoken, requests-toolbelt, langsmith, dataclasses-json, aiohttp, unstructured-client, openai, langchain-core, unstructured, langchain-text-splitters, langchain-openai, langchain, chromadb, langchain-community
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.26.6
#     Uninstalling urllib3-1.26.6:
#       Successfully uninstalled urllib3-1.26.6
#   Attempting uninstall: regex
#     Found existing installation: regex 2021.8.28
#     Uninstalling regex-2021.8.28:
#       Successfully uninstalled regex-2021.8.28
#   Attempting uninstall: python-dotenv
#     Found existing installation: python-dotenv 0.16.0
#     Uninstalling python-dotenv-0.16.0:
#       Successfully uninstalled python-dotenv-0.16.0
#   Attempting uninstall: python-dateutil
#     Found existing installation: python-dateutil 2.8.1
#     Uninstalling python-dateutil-2.8.1:
#       Successfully uninstalled python-dateutil-2.8.1
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.18.1
#     Uninstalling protobuf-3.18.1:
#       Successfully uninstalled protobuf-3.18.1
#   Attempting uninstall: packaging
#     Found existing installation: packaging 21.0
#     Uninstalling packaging-21.0:
#       Successfully uninstalled packaging-21.0
#   Attempting uninstall: nest-asyncio
#     Found existing installation: nest-asyncio 1.5.1
#     Uninstalling nest-asyncio-1.5.1:
#       Successfully uninstalled nest-asyncio-1.5.1
#   Attempting uninstall: mypy-extensions
#     Found existing installation: mypy-extensions 0.4.3
#     Uninstalling mypy-extensions-0.4.3:
#       Successfully uninstalled mypy-extensions-0.4.3
#   Attempting uninstall: idna
#     Found existing installation: idna 3.2
#     Uninstalling idna-3.2:
#       Successfully uninstalled idna-3.2
#   Attempting uninstall: charset-normalizer
#     Found existing installation: charset-normalizer 2.0.6
#     Uninstalling charset-normalizer-2.0.6:
#       Successfully uninstalled charset-normalizer-2.0.6
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2021.5.30
#     Uninstalling certifi-2021.5.30:
#       Successfully uninstalled certifi-2021.5.30
#   Attempting uninstall: async-timeout
#     Found existing installation: async-timeout 3.0.1
#     Uninstalling async-timeout-3.0.1:
#       Successfully uninstalled async-timeout-3.0.1
#   Attempting uninstall: aiohttp
#     Found existing installation: aiohttp 3.7.4.post0
#     Uninstalling aiohttp-3.7.4.post0:
#       Successfully uninstalled aiohttp-3.7.4.post0
#   Attempting uninstall: openai
#     Found existing installation: openai 0.27.4
#     Uninstalling openai-0.27.4:
#       Successfully uninstalled openai-0.27.4
#   Attempting uninstall: chromadb
#     Found existing installation: chromadb 0.5.3
#     Uninstalling chromadb-0.5.3:
#       Successfully uninstalled chromadb-0.5.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# eth-brownie 1.16.4 requires aiohttp==3.7.4.post0, but you have aiohttp 3.9.5 which is incompatible.
# eth-brownie 1.16.4 requires async-timeout==3.0.1, but you have async-timeout 4.0.3 which is incompatible.
# eth-brownie 1.16.4 requires certifi==2021.5.30, but you have certifi 2024.6.2 which is incompatible.
# eth-brownie 1.16.4 requires charset-normalizer==2.0.6, but you have charset-normalizer 3.3.2 which is incompatible.
# eth-brownie 1.16.4 requires idna==3.2, but you have idna 3.7 which is incompatible.
# eth-brownie 1.16.4 requires mypy-extensions==0.4.3, but you have mypy-extensions 1.0.0 which is incompatible.
# eth-brownie 1.16.4 requires packaging==21.0, but you have packaging 24.1 which is incompatible.
# eth-brownie 1.16.4 requires protobuf==3.18.0, but you have protobuf 4.25.3 which is incompatible.
# eth-brownie 1.16.4 requires pygments==2.10.0, but you have pygments 2.18.0 which is incompatible.
# eth-brownie 1.16.4 requires python-dateutil==2.8.1, but you have python-dateutil 2.9.0.post0 which is incompatible.
# eth-brownie 1.16.4 requires python-dotenv==0.16.0, but you have python-dotenv 1.0.1 which is incompatible.
# eth-brownie 1.16.4 requires pyyaml==5.4.1, but you have pyyaml 6.0.1 which is incompatible.
# eth-brownie 1.16.4 requires regex==2021.8.28, but you have regex 2024.5.15 which is incompatible.
# eth-brownie 1.16.4 requires requests==2.26.0, but you have requests 2.32.3 which is incompatible.
# eth-brownie 1.16.4 requires tqdm==4.62.3, but you have tqdm 4.66.4 which is incompatible.
# eth-brownie 1.16.4 requires typing-extensions==3.10.0.2, but you have typing-extensions 4.12.2 which is incompatible.
# eth-brownie 1.16.4 requires urllib3==1.26.6, but you have urllib3 2.2.2 which is incompatible.
# eth-brownie 1.16.4 requires websockets==9.1, but you have websockets 12.0 which is incompatible.
# mythx-models 1.9.1 requires python-dateutil==2.8.1, but you have python-dateutil 2.9.0.post0 which is incompatible.
# pythx 1.6.1 requires python-dateutil<2.9.0,>=2.8.0, but you have python-dateutil 2.9.0.post0 which is incompatible.
# web3 5.23.1 requires protobuf<4,>=3.10.0, but you have protobuf 4.25.3 which is incompatible.
# web3 5.23.1 requires websockets<10,>=9.1, but you have websockets 12.0 which is incompatible.
# spacy 3.2.0 requires pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4, but you have pydantic 2.7.4 which is incompatible.
# spacy 3.2.0 requires typer<0.5.0,>=0.3.0, but you have typer 0.12.3 which is incompatible.
# Successfully installed SQLAlchemy-2.0.31 aiohttp-3.9.5 aiosignal-1.3.1 async-timeout-4.0.3 beautifulsoup4-4.12.3 certifi-2021.10.8 charset-normalizer-3.3.2 chromadb-0.5.0 dataclasses-json-0.6.7 deepdiff-7.0.1 distro-1.9.0 emoji-2.12.1 filetype-1.2.0 frozenlist-1.4.1 greenlet-3.0.3 idna-3.7 jsonpatch-1.33 jsonpath-python-1.0.6 jsonpointer-3.0.0 langchain-0.2.2 langchain-community-0.2.3 langchain-core-0.2.10 langchain-openai-0.1.8 langchain-text-splitters-0.2.2 langdetect-1.0.9 langsmith-0.1.82 lxml-5.2.2 marshmallow-3.21.3 mypy-extensions-1.0.0 nest-asyncio-1.6.0 openai-1.31.1 ordered-set-4.1.0 packaging-24.1 protobuf-4.25.3 pypdf-4.2.0 python-dateutil-2.8.2 python-dotenv-1.0.1 python-iso639-2024.4.27 python-magic-0.4.27 rapidfuzz-3.9.3 regex-2021.11.10 requests-toolbelt-1.0.0 soupsieve-2.5 tabulate-0.9.0 tiktoken-0.7.0 typing-inspect-0.9.0 unstructured-0.14.4 unstructured-client-0.23.8 urllib3-1.26.7
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install "unstructured[md]"
# Out:
# Requirement already satisfied: unstructured[md] in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (0.14.4)
# Requirement already satisfied: chardet in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from unstructured[md]) (4.0.0)
# Requirement already satisfied: filetype in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from unstructured[md]) (1.2.0)
# Requirement already satisfied: python-magic in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from unstructured[md]) (0.4.27)
# Requirement already satisfied: lxml in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from unstructured[md]) (5.2.2)
# Requirement already satisfied: nltk in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from unstructured[md]) (3.6.5)
# Requirement already satisfied: tabulate in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from unstructured[md]) (0.9.0)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from unstructured[md]) (2.32.3)
# Requirement already satisfied: beautifulsoup4 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from unstructured[md]) (4.12.3)
# Requirement already satisfied: emoji in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from unstructured[md]) (2.12.1)
# Requirement already satisfied: dataclasses-json in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from unstructured[md]) (0.6.7)
# Requirement already satisfied: python-iso639 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from unstructured[md]) (2024.4.27)
# Requirement already satisfied: langdetect in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from unstructured[md]) (1.0.9)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from unstructured[md]) (1.26.4)
# Requirement already satisfied: rapidfuzz in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from unstructured[md]) (3.9.3)
# Requirement already satisfied: backoff in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from unstructured[md]) (2.2.1)
# Requirement already satisfied: typing-extensions in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from unstructured[md]) (4.12.2)
# Requirement already satisfied: unstructured-client in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from unstructured[md]) (0.23.8)
# Requirement already satisfied: wrapt in /Users/thomaskojoaddaquay/Library/Python/3.10/lib/python/site-packages (from unstructured[md]) (1.12.1)
# Collecting markdown (from unstructured[md])
#   Downloading Markdown-3.6-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: soupsieve>1.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from beautifulsoup4->unstructured[md]) (2.5)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from dataclasses-json->unstructured[md]) (3.21.3)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from dataclasses-json->unstructured[md]) (0.9.0)
# Requirement already satisfied: six in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from langdetect->unstructured[md]) (1.16.0)
# Requirement already satisfied: click in /Users/thomaskojoaddaquay/Library/Python/3.10/lib/python/site-packages (from nltk->unstructured[md]) (8.0.1)
# Requirement already satisfied: joblib in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from nltk->unstructured[md]) (1.1.0)
# Requirement already satisfied: regex>=2021.8.3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from nltk->unstructured[md]) (2021.11.10)
# Requirement already satisfied: tqdm in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from nltk->unstructured[md]) (4.66.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests->unstructured[md]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests->unstructured[md]) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests->unstructured[md]) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests->unstructured[md]) (2021.10.8)
# Collecting certifi>=2017.4.17 (from requests->unstructured[md])
#   Using cached certifi-2024.6.2-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: deepdiff>=6.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from unstructured-client->unstructured[md]) (7.0.1)
# Requirement already satisfied: httpx>=0.27.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from unstructured-client->unstructured[md]) (0.27.0)
# Requirement already satisfied: jsonpath-python>=1.0.6 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from unstructured-client->unstructured[md]) (1.0.6)
# Requirement already satisfied: mypy-extensions>=1.0.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from unstructured-client->unstructured[md]) (1.0.0)
# Requirement already satisfied: nest-asyncio>=1.6.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from unstructured-client->unstructured[md]) (1.6.0)
# Requirement already satisfied: packaging>=23.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from unstructured-client->unstructured[md]) (24.1)
# Requirement already satisfied: pypdf>=4.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from unstructured-client->unstructured[md]) (4.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from unstructured-client->unstructured[md]) (2.8.2)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from unstructured-client->unstructured[md]) (1.0.0)
# Collecting urllib3<3,>=1.21.1 (from requests->unstructured[md])
#   Using cached urllib3-2.2.2-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: ordered-set<4.2.0,>=4.1.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from deepdiff>=6.0->unstructured-client->unstructured[md]) (4.1.0)
# Requirement already satisfied: anyio in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from httpx>=0.27.0->unstructured-client->unstructured[md]) (4.4.0)
# Requirement already satisfied: httpcore==1.* in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from httpx>=0.27.0->unstructured-client->unstructured[md]) (1.0.5)
# Requirement already satisfied: sniffio in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from httpx>=0.27.0->unstructured-client->unstructured[md]) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.27.0->unstructured-client->unstructured[md]) (0.14.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from anyio->httpx>=0.27.0->unstructured-client->unstructured[md]) (1.2.1)
# Downloading Markdown-3.6-py3-none-any.whl (105 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 1.3 MB/s eta 0:00:00 0:00:01
# Using cached certifi-2024.6.2-py3-none-any.whl (164 kB)
# Using cached urllib3-2.2.2-py3-none-any.whl (121 kB)
# Installing collected packages: urllib3, markdown, certifi
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.26.7
#     Uninstalling urllib3-1.26.7:
#       Successfully uninstalled urllib3-1.26.7
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2021.10.8
#     Uninstalling certifi-2021.10.8:
#       Successfully uninstalled certifi-2021.10.8
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# eth-brownie 1.16.4 requires aiohttp==3.7.4.post0, but you have aiohttp 3.9.5 which is incompatible.
# eth-brownie 1.16.4 requires async-timeout==3.0.1, but you have async-timeout 4.0.3 which is incompatible.
# eth-brownie 1.16.4 requires certifi==2021.5.30, but you have certifi 2024.6.2 which is incompatible.
# eth-brownie 1.16.4 requires charset-normalizer==2.0.6, but you have charset-normalizer 3.3.2 which is incompatible.
# eth-brownie 1.16.4 requires idna==3.2, but you have idna 3.7 which is incompatible.
# eth-brownie 1.16.4 requires mypy-extensions==0.4.3, but you have mypy-extensions 1.0.0 which is incompatible.
# eth-brownie 1.16.4 requires packaging==21.0, but you have packaging 24.1 which is incompatible.
# eth-brownie 1.16.4 requires protobuf==3.18.0, but you have protobuf 4.25.3 which is incompatible.
# eth-brownie 1.16.4 requires pygments==2.10.0, but you have pygments 2.18.0 which is incompatible.
# eth-brownie 1.16.4 requires python-dateutil==2.8.1, but you have python-dateutil 2.8.2 which is incompatible.
# eth-brownie 1.16.4 requires python-dotenv==0.16.0, but you have python-dotenv 1.0.1 which is incompatible.
# eth-brownie 1.16.4 requires pyyaml==5.4.1, but you have pyyaml 6.0.1 which is incompatible.
# eth-brownie 1.16.4 requires regex==2021.8.28, but you have regex 2021.11.10 which is incompatible.
# eth-brownie 1.16.4 requires requests==2.26.0, but you have requests 2.32.3 which is incompatible.
# eth-brownie 1.16.4 requires tqdm==4.62.3, but you have tqdm 4.66.4 which is incompatible.
# eth-brownie 1.16.4 requires typing-extensions==3.10.0.2, but you have typing-extensions 4.12.2 which is incompatible.
# eth-brownie 1.16.4 requires urllib3==1.26.6, but you have urllib3 2.2.2 which is incompatible.
# eth-brownie 1.16.4 requires websockets==9.1, but you have websockets 12.0 which is incompatible.
# spacy 3.2.0 requires pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4, but you have pydantic 2.7.4 which is incompatible.
# spacy 3.2.0 requires typer<0.5.0,>=0.3.0, but you have typer 0.12.3 which is incompatible.
# tiktoken 0.7.0 requires regex>=2022.1.18, but you have regex 2021.11.10 which is incompatible.
# Successfully installed certifi-2024.6.2 markdown-3.6 urllib3-2.2.2
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Create database
#
# Create the Chroma DB.

# %%
# from langchain.document_loaders import DirectoryLoader
from langchain_community.document_loaders import DirectoryLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.schema import Document
# from langchain.embeddings import OpenAIEmbeddings
from langchain_openai import OpenAIEmbeddings
from langchain_community.vectorstores import Chroma
import openai 
from dotenv import load_dotenv
import os
import shutil

# Load environment variables. Assumes that project contains .env file with API keys
load_dotenv()
#---- Set OpenAI API key 
# Change environment variable name from "OPENAI_API_KEY" to the name given in 
# your .env file.
openai.api_key = os.environ['OPENAI_API_KEY']

CHROMA_PATH = "chroma"
DATA_PATH = "data"


def main():
    generate_data_store()


def generate_data_store():
    documents = load_documents()
    chunks = split_text(documents)
    save_to_chroma(chunks)


def load_documents():
    loader = DirectoryLoader(DATA_PATH, glob="*.md")
    documents = loader.load()
    return documents


def split_text(documents: list[Document]):
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=100,
        chunk_overlap=100,
        length_function=len,
        add_start_index=True,
    )
    chunks = text_splitter.split_documents(documents)
    print(f"Split {len(documents)} documents into {len(chunks)} chunks.")

    document = chunks[10]
    print(document.page_content)
    print(document.metadata)

    return chunks


def save_to_chroma(chunks: list[Document]):
    # Clear out the database first.
    if os.path.exists(CHROMA_PATH):
        shutil.rmtree(CHROMA_PATH)

    # Create a new DB from the documents.
    db = Chroma.from_documents(
        chunks, OpenAIEmbeddings(), persist_directory=CHROMA_PATH
    )
    db.persist()
    print(f"Saved {len(chunks)} chunks to {CHROMA_PATH}.")


if __name__ == "__main__":
    main()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/thomaskojoaddaquay/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/thomaskojoaddaquay/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# Split 1 documents into 10 chunks.
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/hw/flz4hpj923q_tqcfd_ksvkwm0000gn/T/ipykernel_14624/1837299590.py in <module>
#      69
#      70 if __name__ == "__main__":
# ---> 71     main()
#
# /var/folders/hw/flz4hpj923q_tqcfd_ksvkwm0000gn/T/ipykernel_14624/1837299590.py in main()
#      23
#      24 def main():
# ---> 25     generate_data_store()
#      26
#      27
#
# /var/folders/hw/flz4hpj923q_tqcfd_ksvkwm0000gn/T/ipykernel_14624/1837299590.py in generate_data_store()
#      28 def generate_data_store():
#      29     documents = load_documents()
# ---> 30     chunks = split_text(documents)
#      31     save_to_chroma(chunks)
#      32
#
# /var/folders/hw/flz4hpj923q_tqcfd_ksvkwm0000gn/T/ipykernel_14624/1837299590.py in split_text(documents)
#      48     print(f"Split {len(documents)} documents into {len(chunks)} chunks.")
#      49
# ---> 50     document = chunks[10]
#      51     print(document.page_content)
#      52     print(document.metadata)
#
# IndexError: list index out of range

# %% [markdown]
# ## Query the database
#
# Query the Chroma DB.
